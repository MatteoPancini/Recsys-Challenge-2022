# %%
import pandas as pd
import scipy.sparse as sps

# %%
lenght = pd.read_csv('../Input/data_ICM_length.csv')

# %%
lenght
# Out:
#        item_id  feature_id  data
# 0            0           0     1
# 1            1           0     1
# 2            2           0    21
# 3            3           0     1
# 4            4           0     1
# ...        ...         ...   ...
# 23086    27963           0     1
# 23087    27964           0     1
# 23088    27965           0     1
# 23089    27966           0     1
# 23090    27967           0     2
#
# [23091 rows x 3 columns]

# %%
numberOfEpisodes = lenght['data'].to_numpy()
numberOfEpisodes
# Out:
# array([ 1,  1, 21, ...,  1,  1,  2])

# %%
types['numberOfEpisodes'] = numberOfEpisodes
types
# Out:
#        item_id  feature_id  data  numberOfEpisodes
# 0            0           1     1                 1
# 1            1           3     1                 1
# 2            2           4     1                21
# 3            3           1     1                 1
# 4            4           3     1                 1
# ...        ...         ...   ...               ...
# 23086    27963           1     1                 1
# 23087    27964           2     1                 1
# 23088    27965           1     1                 1
# 23089    27966           1     1                 1
# 23090    27967           4     1                 2
#
# [23091 rows x 4 columns]

# %%
ICM = types.rename(columns={'data':'type'})
ICM
# Out:
#        item_id  feature_id  type  numberOfEpisodes
# 0            0           1     1                 1
# 1            1           3     1                 1
# 2            2           4     1                21
# 3            3           1     1                 1
# 4            4           3     1                 1
# ...        ...         ...   ...               ...
# 23086    27963           1     1                 1
# 23087    27964           2     1                 1
# 23088    27965           1     1                 1
# 23089    27966           1     1                 1
# 23090    27967           4     1                 2
#
# [23091 rows x 4 columns]

# %%
ICM['type']
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 23086    1
# 23087    1
# 23088    1
# 23089    1
# 23090    1
# Name: type, Length: 23091, dtype: int64

# %%
for x in ICM['type']:
    if x == 1:
        print('ciao')
# Out:
# ciao
# ciao
# ciao
# ciao
# ciao
# ciao
# ciao
# ciao
# ciao
# ciao
# ciao
# ciao
# ciao
# ciao
# ciao
# ciao
# ciao
# ciao
# ciao
# ciao
# ciao
# ciao
# ciao
# ciao
# ciao
# ciao
# ciao
# ciao
# ciao
# ciao
# ciao
# ciao
# ciao
# ciao
# ciao
# ciao
# ciao
# ciao
# ciao
# ciao
# ciao
# ciao
# ciao
# ciao
# ciao
# ciao
# ciao
# ciao
# ciao
# ciao
# ciao
# ciao
# ciao
# ciao
# ciao
# ciao
# ciao
# ciao
# ciao
# ciao
# ciao
# ciao
# ciao
# ciao
# ciao
# ciao
# ciao
# ciao
# ciao
# ciao
# ciao
# ciao
# ciao
# ciao
# ciao
# ciao
# ciao
# ciao
# ciao
# ciao
# ciao
# ciao
# ciao
# ciao
# ciao
# ciao
# ciao
# ciao
# ciao
# ciao
# ciao
# ciao
# ciao
# ciao
# ciao
# ciao
# ciao
# ciao
# ciao
# ciao
# ciao
# ciao
# ciao
# ciao
# ciao
# ciao
# ciao
# ciao
# ciao
# ciao
# ciao
# ciao
# ciao
# ciao
# ciao
# ciao
# ciao
# ciao
# ciao
# ciao
# ciao
# ciao
# ciao
# ciao
# ciao
# ciao
# ciao
# ciao
# ciao
# ciao
# ciao
# ciao
# ciao
# ciao
# ciao
# ciao
# ciao
# ciao
# ciao
# ciao
# ciao
# ciao
# ...
